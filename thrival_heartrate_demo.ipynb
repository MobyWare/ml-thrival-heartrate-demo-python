# %% [markdown]
# # Thrival Pittsburgh - ML in Healthcare

# %%
# %matplotlib inline
import AnalyzeHeartRates as thrival

# %%
thrival.showThrivalPlotNoCluster()
# Out:
# 1) data/alice1.txt. Both the spectrum: 129 and amplitude: 129 should had have the same length. The currnet # of samples is: 1.
#  Amplitude (1st five): [  9.27727861e-06   5.50499635e-05   4.64563525e-05   3.16902383e-05
#    1.65128389e-05]
# 2) data/alice2.txt. Both the spectrum: 129 and amplitude: 129 should had have the same length. The currnet # of samples is: 2.
#  Amplitude (1st five): [  5.46923687e-06   2.06126721e-05   3.21235218e-05   1.70196645e-05
#    6.50653933e-06]
# 3) data/bob1.txt. Both the spectrum: 129 and amplitude: 129 should had have the same length. The currnet # of samples is: 3.
#  Amplitude (1st five): [  1.00727156e-05   4.40569136e-05   4.10872430e-05   1.78764908e-05
#    9.31331773e-06]
# Starting plot wihtout clusters ...

# %%
thrival.showThrivalPlotWithCluster()
# Out:
# 1) data/alice1.txt. Both the spectrum: 129 and amplitude: 129 should had have the same length. The currnet # of samples is: 1.
#  Amplitude (1st five): [  9.27727861e-06   5.50499635e-05   4.64563525e-05   3.16902383e-05
#    1.65128389e-05]
# 2) data/alice2.txt. Both the spectrum: 129 and amplitude: 129 should had have the same length. The currnet # of samples is: 2.
#  Amplitude (1st five): [  5.46923687e-06   2.06126721e-05   3.21235218e-05   1.70196645e-05
#    6.50653933e-06]
# 3) data/bob1.txt. Both the spectrum: 129 and amplitude: 129 should had have the same length. The currnet # of samples is: 3.
#  Amplitude (1st five): [  1.00727156e-05   4.40569136e-05   4.10872430e-05   1.78764908e-05
#    9.31331773e-06]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-5da8e2c21b9b> in <module>()
# ----> 1 thrival.showThrivalPlotWithCluster()
#
# ...
